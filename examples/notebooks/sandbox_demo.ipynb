# %% [markdown]
# # Sandbox Demo
#
# Interactively explore the sheath animation by adjusting the voltage and pressure.

# %%
from dpf2.visualization import sheath_widget
sheath_widget()

# %%
LESSON_CONFIGS = {
    "intro": {"voltage": 1.0, "pressure": 0.1},
    "high_voltage": {"voltage": 4.0, "pressure": 0.2},
    "low_pressure": {"voltage": 2.0, "pressure": 0.05},
}
LESSON_CONFIGS
