# %% [markdown]
# # UQ Sampling
# Demonstrate Latin hypercube and Sobol sequence sampling.

# %%
from dpf2.uq.sampling import latin_hypercube, sobol_sample
bounds = {"capacitance": (1e-6, 5e-6), "inductance": (1e-8, 5e-8)}
latin_hypercube(bounds, 4, seed=0)
